# %% [markdown]
# # RETAIL CASE STUDY

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
cust = pd.read_csv("C:/Users/Lenovo/Downloads/Python Foundation Case Study 1 - Retail Case Study/Customer.csv")
cust
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
trans = pd.read_csv("C:/Users/Lenovo/Downloads/Python Foundation Case Study 1 - Retail Case Study/Transactions.csv")
trans
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# 0       -5  -772  405.300  -4265.300     e-Shop
# 1       -5 -1497  785.925  -8270.925     e-Shop
# 2       -2  -791  166.110  -1748.110   TeleShop
# 3       -3 -1363  429.345  -4518.345     e-Shop
# 4       -2  -791  166.110  -1748.110   TeleShop
# ...    ...   ...      ...        ...        ...
# 23048    1  1264  132.720   1396.720     e-Shop
# 23049    1   677   71.085    748.085     e-Shop
# 23050    4  1052  441.840   4649.840        MBR
# 23051    3  1142  359.730   3785.730   TeleShop
# 23052    1   447   46.935    493.935   TeleShop
#
# [23053 rows x 10 columns]

# %%
prod = pd.read_csv("C:/Users/Lenovo/Downloads/Python Foundation Case Study 1 - Retail Case Study/prod_cat_info.csv")
prod
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# 11              4              Bags                  1                 Mens
# 12              4              Bags                  4                Women
# 13              5             Books                  7              Fiction
# 14              5             Books                 12             Academic
# 15              5             Books                 10          Non-Fiction
# 16              5             Books                 11             Children
# 17              5             Books                  3               Comics
# 18              5             Books                  6                  DIY
# 19              6  Home and kitchen                  2           Furnishing
# 20              6  Home and kitchen                 10              Kitchen
# 21              6  Home and kitchen                 11                 Bath
# 22              6  Home and kitchen                 12                Tools

# %% [raw]
# 1.Merge the datasets Customers,Product Hierarchy and Transactions as Customer_Final.Ensure to keep all customers who have done transtions with us and select the join type accordingly.

# %%
table_1 = pd.merge(cust, trans, how= 'right', left_on='customer_Id', right_on = 'cust_id')
Customer_Final= pd.merge(table_1, prod, how= 'left', left_on='prod_cat_code', right_on = 'prod_cat_code')
Customer_Final
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0           270351  26-09-1981      M        5.0     80712190438   270351
# 1           270351  26-09-1981      M        5.0     80712190438   270351
# 2           270351  26-09-1981      M        5.0     80712190438   270351
# 3           270384  11-05-1973      F        8.0     29258453508   270384
# 4           270384  11-05-1973      F        8.0     29258453508   270384
# ...            ...         ...    ...        ...             ...      ...
# 99288       271961  15-01-1982      M        1.0     77960931771   271961
# 99289       271961  15-01-1982      M        1.0     77960931771   271961
# 99290       271961  15-01-1982      M        1.0     77960931771   271961
# 99291       271961  15-01-1982      M        1.0     77960931771   271961
# 99292       271961  15-01-1982      M        1.0     77960931771   271961
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# 0      28-02-2014                 1              1   -5  -772  405.300
# 1      28-02-2014                 1              1   -5  -772  405.300
# 2      28-02-2014                 1              1   -5  -772  405.300
# 3      27-02-2014                 5              3   -5 -1497  785.925
# 4      27-02-2014                 5              3   -5 -1497  785.925
# ...           ...               ...            ...  ...   ...      ...
# 99288  25-01-2011                11              5    1   447   46.935
# 99289  25-01-2011                11              5    1   447   46.935
# 99290  25-01-2011                11              5    1   447   46.935
# 99291  25-01-2011                11              5    1   447   46.935
# 99292  25-01-2011                11              5    1   447   46.935
#
#        total_amt Store_type     prod_cat  prod_sub_cat_code  prod_subcat
# 0      -4265.300     e-Shop     Clothing                  4         Mens
# 1      -4265.300     e-Shop     Clothing                  1        Women
# 2      -4265.300     e-Shop     Clothing                  3         Kids
# 3      -8270.925     e-Shop  Electronics                  4      Mobiles
# 4      -8270.925     e-Shop  Electronics                  5    Computers
# ...          ...        ...          ...                ...          ...
# 99288    493.935   TeleShop        Books                 12     Academic
# 99289    493.935   TeleShop        Books                 10  Non-Fiction
# 99290    493.935   TeleShop        Books                 11     Children
# 99291    493.935   TeleShop        Books                  3       Comics
# 99292    493.935   TeleShop        Books                  6          DIY
#
# [99293 rows x 17 columns]

# %% [raw]
# 2. Prepare a summary report for the merged data set.
# a. Get the column name and their corresponding data types.

# %%
Customer_Final.dtypes
# Out:
# customer_Id            int64
# DOB                   object
# Gender                object
# city_code            float64
# transaction_id         int64
# cust_id                int64
# tran_date             object
# prod_subcat_code       int64
# prod_cat_code          int64
# Qty                    int64
# Rate                   int64
# Tax                  float64
# total_amt            float64
# Store_type            object
# prod_cat              object
# prod_sub_cat_code      int64
# prod_subcat           object
# dtype: object

# %%
b. Top/Bottom 10 observations.

# %%
Customer_Final.head(10)
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 99283       270911  22-05-1970      M        2.0     72870271171   270911
# 99284       270911  22-05-1970      M        2.0     72870271171   270911
# 99285       270911  22-05-1970      M        2.0     72870271171   270911
# 99286       270911  22-05-1970      M        2.0     72870271171   270911
# 99287       271961  15-01-1982      M        1.0     77960931771   271961
# 99288       271961  15-01-1982      M        1.0     77960931771   271961
# 99289       271961  15-01-1982      M        1.0     77960931771   271961
# 99290       271961  15-01-1982      M        1.0     77960931771   271961
# 99291       271961  15-01-1982      M        1.0     77960931771   271961
# 99292       271961  15-01-1982      M        1.0     77960931771   271961
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# 99283  25-01-2011                11              5    3  1142  359.730
# 99284  25-01-2011                11              5    3  1142  359.730
# 99285  25-01-2011                11              5    3  1142  359.730
# 99286  25-01-2011                11              5    3  1142  359.730
# 99287  25-01-2011                11              5    1   447   46.935
# 99288  25-01-2011                11              5    1   447   46.935
# 99289  25-01-2011                11              5    1   447   46.935
# 99290  25-01-2011                11              5    1   447   46.935
# 99291  25-01-2011                11              5    1   447   46.935
# 99292  25-01-2011                11              5    1   447   46.935
#
#        total_amt Store_type prod_cat  prod_sub_cat_code  prod_subcat
# 99283   3785.730   TeleShop    Books                 10  Non-Fiction
# 99284   3785.730   TeleShop    Books                 11     Children
# 99285   3785.730   TeleShop    Books                  3       Comics
# 99286   3785.730   TeleShop    Books                  6          DIY
# 99287    493.935   TeleShop    Books                  7      Fiction
# 99288    493.935   TeleShop    Books                 12     Academic
# 99289    493.935   TeleShop    Books                 10  Non-Fiction
# 99290    493.935   TeleShop    Books                 11     Children
# 99291    493.935   TeleShop    Books                  3       Comics
# 99292    493.935   TeleShop    Books                  6          DIY

# %%
Customer_Final.tail(10)
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 99283       270911  22-05-1970      M        2.0     72870271171   270911
# 99284       270911  22-05-1970      M        2.0     72870271171   270911
# 99285       270911  22-05-1970      M        2.0     72870271171   270911
# 99286       270911  22-05-1970      M        2.0     72870271171   270911
# 99287       271961  15-01-1982      M        1.0     77960931771   271961
# 99288       271961  15-01-1982      M        1.0     77960931771   271961
# 99289       271961  15-01-1982      M        1.0     77960931771   271961
# 99290       271961  15-01-1982      M        1.0     77960931771   271961
# 99291       271961  15-01-1982      M        1.0     77960931771   271961
# 99292       271961  15-01-1982      M        1.0     77960931771   271961
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# 99283  25-01-2011                11              5    3  1142  359.730
# 99284  25-01-2011                11              5    3  1142  359.730
# 99285  25-01-2011                11              5    3  1142  359.730
# 99286  25-01-2011                11              5    3  1142  359.730
# 99287  25-01-2011                11              5    1   447   46.935
# 99288  25-01-2011                11              5    1   447   46.935
# 99289  25-01-2011                11              5    1   447   46.935
# 99290  25-01-2011                11              5    1   447   46.935
# 99291  25-01-2011                11              5    1   447   46.935
# 99292  25-01-2011                11              5    1   447   46.935
#
#        total_amt Store_type prod_cat  prod_sub_cat_code  prod_subcat
# 99283   3785.730   TeleShop    Books                 10  Non-Fiction
# 99284   3785.730   TeleShop    Books                 11     Children
# 99285   3785.730   TeleShop    Books                  3       Comics
# 99286   3785.730   TeleShop    Books                  6          DIY
# 99287    493.935   TeleShop    Books                  7      Fiction
# 99288    493.935   TeleShop    Books                 12     Academic
# 99289    493.935   TeleShop    Books                 10  Non-Fiction
# 99290    493.935   TeleShop    Books                 11     Children
# 99291    493.935   TeleShop    Books                  3       Comics
# 99292    493.935   TeleShop    Books                  6          DIY

# %%
c.”Five Number Summary ” for continuous variables( min,Q1,median,Q3 and max)

# %%
Customer_Final.describe()
# Out:
#          customer_Id     city_code  transaction_id        cust_id  \
# count   99293.000000  99257.000000    9.929300e+04   99293.000000
# mean   271030.010635      5.467221    5.007320e+10  271030.010635
# std      2429.333624      2.859343    2.899361e+10    2429.333624
# min    266783.000000      1.000000    3.268991e+06  266783.000000
# 25%    268956.000000      3.000000    2.492150e+10  268956.000000
# 50%    270982.000000      5.000000    5.011083e+10  270982.000000
# 75%    273120.000000      8.000000    7.528121e+10  273120.000000
# max    275265.000000     10.000000    9.998755e+10  275265.000000
#
#        prod_subcat_code  prod_cat_code           Qty          Rate  \
# count      99293.000000   99293.000000  99293.000000  99293.000000
# mean           6.796894       4.003243      2.438017    637.919884
# std            3.609439       1.563991      2.260726    621.576326
# min            1.000000       1.000000     -5.000000  -1499.000000
# 25%            4.000000       3.000000      1.000000    313.000000
# 50%            7.000000       5.000000      3.000000    713.000000
# 75%           10.000000       5.000000      4.000000   1109.000000
# max           12.000000       6.000000      5.000000   1500.000000
#
#                 Tax     total_amt  prod_sub_cat_code
# count  99293.000000  99293.000000       99293.000000
# mean     248.873736   2114.616420           6.806985
# std      187.014422   2502.306768           3.615952
# min        7.350000  -8270.925000           1.000000
# 25%       98.280000    762.450000           4.000000
# 50%      199.920000   1761.370000           7.000000
# 75%      366.975000   3585.725000          10.000000
# max      787.500000   8287.500000          12.000000

# %%
d. Frequency tables for all categorical variables.

# %%
for column in Customer_Final.select_dtypes(include=['object']).columns:
    display(pd.crosstab(index=Customer_Final[column], columns='% observations', normalize='columns')*100)
# Out:
# col_0       % observations
# DOB
# 01-01-1972        0.018128
# 01-01-1978        0.021150
# 01-01-1979        0.013093
# 01-01-1980        0.039278
# 01-01-1981        0.019135
# ...                    ...
# 29-12-1988        0.009064
# 29-12-1989        0.013093
# 29-12-1990        0.033235
# 29-12-1991        0.008057
# 29-12-1992        0.012085
#
# [3987 rows x 1 columns]
# col_0   % observations
# Gender
# F            48.564779
# M            51.435221
# col_0      % observations
# tran_date
# 1/1/2012         0.049349
# 1/1/2013         0.085605
# 1/1/2014         0.140997
# 1/10/2011        0.089634
# 1/10/2012        0.085605
# ...                   ...
# 9/8/2012         0.108769
# 9/8/2013         0.110783
# 9/9/2011         0.119847
# 9/9/2012         0.089634
# 9/9/2013         0.110783
#
# [1129 rows x 1 columns]
# col_0           % observations
# Store_type
# Flagship store       19.955082
# MBR                  20.116222
# TeleShop             19.457565
# e-Shop               40.471131
# col_0             % observations
# prod_cat
# Bags                    4.024453
# Books                  36.673280
# Clothing                8.943229
# Electronics            24.664377
# Footwear                9.061062
# Home and kitchen       16.633600
# col_0                % observations
# prod_subcat
# Academic                   6.112213
# Audio and video            4.932875
# Bath                       4.158400
# Cameras                    4.932875
# Children                   6.112213
# Comics                     6.112213
# Computers                  4.932875
# DIY                        6.112213
# Fiction                    6.112213
# Furnishing                 4.158400
# Kids                       6.001430
# Kitchen                    4.158400
# Mens                       8.013657
# Mobiles                    4.932875
# Non-Fiction                6.112213
# Personal Appliances        4.932875
# Tools                      4.158400
# Women                      8.013657

# %%
3.Generate histograms for all continuous variables and frequency bars for all categorical variables.

# %%
Customer_Final.select_dtypes(include=['object']).columns
# Out:
# Index(['DOB', 'Gender', 'tran_date', 'Store_type', 'prod_cat', 'prod_subcat'], dtype='object')

# %%
Customer_Final.select_dtypes(include=['int64']).columns
# Out:
# Index(['customer_Id', 'transaction_id', 'cust_id', 'prod_subcat_code',
#        'prod_cat_code', 'Qty', 'Rate', 'prod_sub_cat_code'],
#       dtype='object')

# %%
##Gender
Customer_Final.groupby('Gender').customer_Id.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
##Store Type
Customer_Final.groupby('Store_type').customer_Id.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Store_type'>

# %%
##Product Category
Customer_Final.groupby('prod_cat').customer_Id.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='prod_cat'>

# %%
##Product Sub-Category
Customer_Final.groupby('prod_subcat').customer_Id.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='prod_subcat'>

# %%
##Rate
plt.title('HISTOGRAM')
Customer_Final.Rate.plot(kind='hist')
plt.show()

# %%
##Quantity
plt.title('HISTOGRAM')
Customer_Final.Qty.plot(kind='hist')
plt.show()

# %%
4. Calculate the following information using the merged dataset.
a. Time period of the available transaction data.

# %%
Customer_Final["tran_date"] = pd.to_datetime(Customer_Final["tran_date"])
min_date = Customer_Final["tran_date"].min()
max_date = Customer_Final["tran_date"].max()
print("Time period of the available transaction data is from "+ pd.Timestamp.strftime(min_date,format="%d-%m-%Y") + " to " + pd.Timestamp.strftime(max_date,format="%d-%m-%Y"))
# Out:
# Time period of the available transaction data is from 02-01-2011 to 02-12-2014

# %% [raw]
# b. Count of transactions where the total amount of transaction was negative.

# %%
negative_transaction = Customer_Final.loc[Customer_Final["total_amt"] < 0,"transaction_id"].count()
print("Count of transactions where the total amount of transaction was negative is",negative_transaction)
# Out:
# Count of transactions where the total amount of transaction was negative is 9294

# %%
5. Analyze which product categories are popular among females vs males customers.

# %%
product_gender = Customer_Final.groupby(["Gender","prod_cat"])[["Qty"]].sum().reset_index()
product_gender
product_gender.pivot(index="Gender",columns="prod_cat",values="Qty")
# Out:
# prod_cat  Bags  Books  Clothing  Electronics  Footwear  Home and kitchen
# Gender
# F         4724  42420     10275        29160     11148             19580
# M         4692  45522     11244        32380     10665             20164

# %%
6. Which city code has the maximum customers and what was the percentage of customers from that city?

# %%
customer_group = Customer_Final.groupby('city_code')['customer_Id'].count().sort_values(ascending =False)
customer_group
# Out:
# city_code
# 4.0     10571
# 3.0     10467
# 7.0     10258
# 5.0     10116
# 10.0     9976
# 8.0      9965
# 2.0      9843
# 1.0      9717
# 9.0      9214
# 6.0      9130
# Name: customer_Id, dtype: int64

# %%
plt.figure(figsize=(8,5))
customer_group.plot(kind="bar")
plt.xlabel("City Code")
plt.ylabel("No. of customers")
plt.yticks(np.arange(0, 3500, step=500))
plt.show()

# %%
percentage = round((customer_group[4.0] / customer_group.sum()) * 100,2)
percentage
10.52
print("City code 4.0 has the maximum customers and the percentage of customers from that city is ",percentage)
# Out:
# City code 4.0 has the maximum customers and the percentage of customers from that city is  10.65

# %%
7. Which store type sells the maximum products by value and by quantity.

# %%
Customer_Final.groupby("Store_type")["Qty","Rate"].sum().sort_values(by="Qty",ascending=False)
print('e-Shop store sell the maximum products by value and by quantity')
# Out:
# e-Shop store sell the maximum products by value and by quantity
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_9080/1998932430.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Customer_Final.groupby("Store_type")["Qty","Rate"].sum().sort_values(by="Qty",ascending=False)

# %% [raw]
# 8. What was the total amount earned from the ‘Electronics’ and ‘Clothing’ categories from Flagship Stores?

# %%
store_group = round(Customer_Final.pivot_table(index = "prod_cat",columns="Store_type", values="total_amt", aggfunc='sum'),2)

# %%
store_group.loc[["Clothing","Electronics"],"Flagship store"]
store_group.loc[["Clothing","Electronics"],"Flagship store"].sum()
# Out:
# 14658949.889999999

# %%
9. What was the total amount earned from ‘Male’ customers under the ‘Electronics’ category.

# %%
gender_group = round(Customer_Final.pivot_table(index = "prod_cat",columns="Gender", values="total_amt", aggfunc='sum'),2)
gender_group
# Out:
# Gender                      F            M
# prod_cat
# Bags               4155971.30   4093445.98
# Books             36988153.41  39875836.65
# Clothing           9080252.41   9672238.48
# Electronics       25096771.05  28515547.12
# Footwear           9607658.97   9044016.15
# Home and kitchen  16528709.34  17204301.92

# %%
male_earning = gender_group.loc["Electronics","M"]
print("The total amount earned from Male customers under the Electronics category is",male_earning)
# Out:
# The total amount earned from Male customers under the Electronics category is 28515547.12

# %%
10. How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts.

# %%
pos_trans = Customer_Final.loc[Customer_Final["total_amt"]>0,:]
pos_trans

unique_trans = pos_trans.groupby(['customer_Id','prod_cat','prod_subcat'])['transaction_id'].count().reset_index()
unique_trans

unique_trans_count = unique_trans.groupby('customer_Id')['transaction_id'].count().reset_index()
unique_trans_count.head()

unique_trans_count[unique_trans_count['transaction_id'] > 10]

print('There are no unique transactions greater than 10')
# Out:
# There are no unique transactions greater than 10

# %%
11. For all customers aged between 25-35, find out-
a. What was the total amount spent for ‘Electronics’ and ‘Books’ product categories?

# %%
Customer_Final["DOB"] = pd.to_datetime(Customer_Final["DOB"], format="%d-%m-%Y")
now = pd.Timestamp('now')
Customer_Final['DOB'] = pd.to_datetime(Customer_Final['DOB'], format='%m%d%y')    
Customer_Final['DOB'] = Customer_Final['DOB'].where(Customer_Final['DOB'] < now, Customer_Final['DOB'] -  np.timedelta64(100, 'Y'))   
Customer_Final['AGE'] = (now - Customer_Final['DOB']).astype('<m8[Y]')
Customer_Final.head()
# Out:
#    customer_Id        DOB Gender  city_code  transaction_id  cust_id  \
# 0       270351 1981-09-26      M        5.0     80712190438   270351
# 1       270351 1981-09-26      M        5.0     80712190438   270351
# 2       270351 1981-09-26      M        5.0     80712190438   270351
# 3       270384 1973-05-11      F        8.0     29258453508   270384
# 4       270384 1973-05-11      F        8.0     29258453508   270384
#
#    tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0 2014-02-28                 1              1   -5  -772  405.300  -4265.300
# 1 2014-02-28                 1              1   -5  -772  405.300  -4265.300
# 2 2014-02-28                 1              1   -5  -772  405.300  -4265.300
# 3 2014-02-27                 5              3   -5 -1497  785.925  -8270.925
# 4 2014-02-27                 5              3   -5 -1497  785.925  -8270.925
#
#   Store_type     prod_cat  prod_sub_cat_code prod_subcat   AGE
# 0     e-Shop     Clothing                  4        Mens  40.0
# 1     e-Shop     Clothing                  1       Women  40.0
# 2     e-Shop     Clothing                  3        Kids  40.0
# 3     e-Shop  Electronics                  4     Mobiles  48.0
# 4     e-Shop  Electronics                  5   Computers  48.0

# %%
Customer_Final['Age_cat'] = pd.cut(Customer_Final['AGE'],bins=[24,35,46,57],labels=['25-35','36-46','47-57'],include_lowest=True)

# grouping the dataframe 'customer_final' on the basis of 'Age_cat' and 'prod_cat'
customer_25_35 = Customer_Final.groupby(['Age_cat','prod_cat'])['total_amt'].sum()

customer_25_35.loc['25-35',['Books','Electronics']]

print("Total amount spent on 'Electronics' and 'Books' product categories is", 
      customer_25_35.loc['25-35',['Books','Electronics']].sum().round(2))
# Out:
# Total amount spent on 'Electronics' and 'Books' product categories is 37180730.6

# %%
b. What was the total amount spent by these customers between 1st Jan, 2014 to 1st March, 2014 ?

# %%
# filtering out data that belongs to the 'age_cat' = 25-35
customer_total_amount_25_35 = Customer_Final[Customer_Final['Age_cat']=='25-35']

# getting all the data with transaction date between 1st Jan 2014 to 1st Mar 2014?
total_amount = customer_total_amount_25_35[(customer_total_amount_25_35['tran_date'] >='2014-01-01') & (customer_total_amount_25_35['tran_date'] <='2014-03-01')]

# %%
print('The total amount spent by customers aged 25-35 between 1st Jan 2014 to 1st Mar 2014 is',
      total_amount['total_amt'].sum())
# Out:
# The total amount spent by customers aged 25-35 between 1st Jan 2014 to 1st Mar 2014 is 1929400.7199999997
